# %%
with open('http.txt','r') as f:
    proxies = f.read().splitlines()

# %%
len(proxies)
# Out:
# 37901

# %%
import numpy as np
'http://'+np.random.choice(proxies)
# Out:
# 'http://104.16.217.155:80'

# %%
x=2

# %%
try:
    if x==2:
        raise Exception('x is 2')
    print("x is not 2")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: x is 2

# %%
from bs4 import BeautifulSoup
import asyncio
from multiprocessing import Process, current_process
from aiohttp import ClientSession, ClientTimeout

# %%
import requests

http_response = requests.get("https://myanimelist.net/anime/16498/Shingeki_no_Kyojin")

# %%
soup = BeautifulSoup(http_response.text, 'html.parser')

# %%
aa = soup.find('p',attrs={'itemprop':'description'})
aa.text
# Out:
# 'Centuries ago, mankind was slaughtered to near extinction by monstrous humanoid creatures called Titans, forcing humans to hide in fear behind enormous concentric walls. What makes these giants truly terrifying is that their taste for human flesh is not born out of hunger but what appears to be out of pleasure. To ensure their survival, the remnants of humanity began living within defensive barriers, resulting in one hundred years without a single titan encounter. However, that fragile calm is soon shattered when a colossal Titan manages to breach the supposedly impregnable outer wall, reigniting the fight for survival against the man-eating abominations.\n\r\nAfter witnessing a horrific personal loss at the hands of the invading creatures, Eren Yeager dedicates his life to their eradication by enlisting into the Survey Corps, an elite military unit that combats the merciless humanoids outside the protection of the walls. Eren, his adopted sister Mikasa Ackerman, and his childhood f
# ...

# %%
import pandas as pd
a = pd.DataFrame({'a':[1,2,3,4],'b':[4,5,6,7]})
b = pd.DataFrame({'c':[1,2],'d':[4,5]})

# %%
c=pd.concat([a,b],axis=1)

# %%
df = pd.read_csv('all_anime_urls copy.csv',chunksize=5)
counter = 0
store = []
for i in df:    
    store.append(i)
    counter += 1
    if counter == 5:
        break

# %%
store[1]
# Out:
#                                                  url
# 5  https://myanimelist.net/anime/1892/YAT_Anshin_...
# 6  https://myanimelist.net/anime/31173/Akagami_no...
# 7  https://myanimelist.net/anime/43239/Xiao_Fa_Mi...
# 8  https://myanimelist.net/anime/6641/Tonari_no_8...
# 9  https://myanimelist.net/anime/8935/Nekketsu_Uc...

# %%
store[1].loc[[6,7],['blas','ble']] = [[1,2],[3,4]]

# %%
a = pd.DataFrame([{'a':1,'b':2},{'b':4}])
b = pd.DataFrame([{'b':9},{'b':14}])

# %%
a
# Out:
#      a  b
# 0  1.0  2
# 1  NaN  4

# %%
a.loc[a.index,b.columns] = b.values

# %%
a
# Out:
#      a   b
# 0  1.0   9
# 1  NaN  14

# %%
store[1]
# Out:
#                                                  url  blas  ble
# 5  https://myanimelist.net/anime/1892/YAT_Anshin_...   NaN  NaN
# 6  https://myanimelist.net/anime/31173/Akagami_no...   1.0  2.0
# 7  https://myanimelist.net/anime/43239/Xiao_Fa_Mi...   3.0  4.0
# 8  https://myanimelist.net/anime/6641/Tonari_no_8...   NaN  NaN
# 9  https://myanimelist.net/anime/8935/Nekketsu_Uc...   NaN  NaN

# %%
store[1]['url']
# Out:
# 5    https://myanimelist.net/anime/1892/YAT_Anshin_...
# 6    https://myanimelist.net/anime/31173/Akagami_no...
# 7    https://myanimelist.net/anime/43239/Xiao_Fa_Mi...
# 8    https://myanimelist.net/anime/6641/Tonari_no_8...
# 9    https://myanimelist.net/anime/8935/Nekketsu_Uc...
# Name: url, dtype: object

# %%
df

# %%
df[0].loc[1000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df[0].loc[1000]
#
# TypeError: 'TextFileReader' object is not subscriptable

# %%
d = pd.DataFrame()

# %%
for i in

# %%
a.concat(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_56547/2959602145.py in ?()
# ----> 1 a.concat(b)
#
# ~/miniconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
aa = soup.find_all('div',attrs={'class':'spaceit_pad'})
[' '.join(i.text.strip().split()) for i in aa]
# Out:
# ['Synonyms: AoT, SnK',
#  'Japanese: 進撃の巨人',
#  'English: Attack on Titan',
#  'German: Attack on Titan',
#  'Spanish: Ataque a los Titanes',
#  "French: L'Attaque des Titans",
#  'Type: TV',
#  'Episodes: 25',
#  'Status: Finished Airing',
#  'Aired: Apr 7, 2013 to Sep 29, 2013',
#  'Premiered: Spring 2013',
#  'Broadcast: Sundays at 01:58 (JST)',
#  'Producers: Production I.G, Dentsu, Mainichi Broadcasting System, Pony Canyon, Kodansha, Pony Canyon Enterprises',
#  'Licensors: Funimation',
#  'Studios: Wit Studio',
#  'Source: Manga',
#  'Genres: ActionAction, Award WinningAward Winning, DramaDrama, SuspenseSuspense',
#  'Themes: GoreGore, MilitaryMilitary, SurvivalSurvival',
#  'Demographic: ShounenShounen',
#  'Duration: 24 min. per ep.',
#  'Rating: R - 17+ (violence & profanity)',
#  'Score: 8.561 (scored by 29639902,963,990 users) 1 indicates a weighted score.',
#  "Ranked: #1142 2 based on the top anime page. Please note that 'Not yet aired' and 'R18+' titles are excluded.",
# ...

# %%
async def fetch_urls(url,session,a_set_storage,failed_ones):
    
    try:
        async with session.get(url, timeout=ClientTimeout(total=10)) as response:
            if response.status != 200:
                raise Exception(response.status,"Something went wrong")
            html_response = await response.text()
            soup =  BeautifulSoup(html_response, 'html.parser')
            a_set_storage.update(i.get('href') for i in soup.find_all('a',attrs={'class':'hoverinfo_trigger'}))
    except Exception as e:
        print(e)
        failed_ones.update([url])

# %%
async def process_batch(start,end, a_set_storage,failed_ones):
    async with ClientSession() as session:
        tasks = [fetch_urls(f'https://myanimelist.net/topanime.php?type=bypopularity&limit={no}',
                            session,a_set_storage,failed_ones) 
                 for no in range(start,end,50)]
        return await asyncio.gather(*tasks)

# %%
all_anime_urls = set()
failed_ones = set()

for i in zip(range(0,28701,2500),range(2500,28701,2500)):
    print(i)
    asyncio.run(process_batch(i[0],i[1],all_anime_urls,failed_ones))
# Out:
# (0, 2500)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 6
#       4 for i in zip(range(0,28701,2500),range(2500,28701,2500)):
#       5     print(i)
# ----> 6     asyncio.run(process_batch(i[0],i[1],all_anime_urls,failed_ones))
#
# File ~/miniconda3/lib/python3.13/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# ...

# %%
# Out:
# (0, 2500)
# (2500, 5000)
# (5000, 7500)
# (7500, 10000)
# (10000, 12500)
# (12500, 15000)
# (15000, 17500)
# (17500, 20000)
# (20000, 22500)
# (22500, 25000)
# (25000, 27500)

# %%
28701-27500
# Out:
# 1201

# %%
1200/50
# Out:
# 24.0

# %% [markdown]
# 28701

# %%
import pandas as pd
pd.DataFrame({1,2,3},columns=['a'])
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %%
# Simulate async I/O-bound task
async def fetch_url(url):
    delay = random.uniform(0.5, 2.0)
    await asyncio.sleep(delay)  # Simulate network delay
    print(f"[{current_process().name}] Fetched {url} in {delay:.2f} sec")
    return f"{url} content"

# Run async tasks in a process
def process_task(urls):
    async def main():
        tasks = [fetch_url(url) for url in urls]
        await asyncio.gather(*tasks)

    asyncio.run(main())

# URLs for each process
url_batches = [
    [f"https://example.com/page{i}" for i in range(5)],
    [f"https://example.org/data{i}" for i in range(5)],
]

if __name__ == "__main__":
    start = time.time()

    processes = []
    for urls in url_batches:
        p = Process(target=process_task, args=(urls,))
        processes.append(p)
        p.start()

    for p in processes:
        p.join()

    print(f"\nTotal time: {time.time() - start:.2f} seconds")

# %%
a={1,2}
a.update([3])

# %%
a
# Out:
# {1, 2, 3}

# %%
def x(a_list):
    a_list.update([1,2,3])

a={67}
x(a)
a
# Out:
# {1, 2, 3, 67}

# %%
a+[1,2]
# Out:
# [67, [1, 2, 3], 1, 2]

# %%
anime_urls = list_popular_anime()
# Out:
# 117800

# %%
len(anime_urls)
# Out:
# 7148

# %%
soup = get_soup('https://myanimelist.net/topanime.php?type=bypopularity&limit=7300')

# %%
sdsdsd = [i.get('href') for i in soup.find_all('a',attrs={'class':'hoverinfo_trigger'})]

# %%
for i in sdsdsd:
    if i in anime_urls:
        print(True)
    else:
        print(False)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
asas=get_soup('https://myanimelist.net/topanime.php?type=bypopularity&limit=5000000')

# %%
asas = asas.find_all('a',attrs={'class':'hoverinfo_trigger'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 asas = asas.find_all('a',attrs={'class':'hoverinfo_trigger'})
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
len(set([i.get('href') for i in asas]))
# Out:
# 50

# %%
set.update()

# %%
a={1,2}
a.update([3,4,2])
a
# Out:
# {1, 2, 3, 4}

# %%
[i.href for i in soup.find_all('a',attrs={'class':'hoverinfo_trigger'}) if i.text != '\n\n']
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
