# %%
url = "https://www.youtube.com/watch?v=XVJaqRSrEZA"

# %%
import re

re.findall(r"(?:v=)([\w-]{11})", url)
# Out:
# ['XVJaqRSrEZA']

# %%
import re

def extract_youtube_video_id(url):
    # Regular expression to capture the video ID
    pattern = r'(?:v=|\/)([0-9A-Za-z_-]{11}).*'
    match = re.search(pattern, url)
    if match:
        return match.group(1)
    return None

# %%
pattern = r'(?:v=|\/)([0-9A-Za-z_-]{11}).*'
re.search(pattern, "https://www.youtube.com/watch?v=29XE10U6o-oc&t=6s")
# Out:
# <re.Match object; span=(30, 49), match='v=29XE10U6o-oc&t=6s'>

# %%
re.search(pattern, "https://www.youtube.com/watch?v=uyiG6uw-6pA&t=230s").group(1)
# Out:
# 'uyiG6uw-6pA'

# %%
extract_youtube_video_id("https://www.youtube.com/watch?v=29XE10U6ooc&t=6s")
# Out:
# '29XE10U6ooc'

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Replace with the YouTube video ID
video_id = "ZPUtA3W-7_I"
# video_id = "giqjHxdN-Ok"
# video_id = "95wUTeGHG1k"

# %%
# ytt_api = YouTubeTranscriptApi()
# transcript_list = ytt_api.fetch(video_id)

# %%
ytt_api = YouTubeTranscriptApi()
transcript_list = ytt_api.get_transcript(video_id, languages=['en','hi'])

# %%
transcript_list[:5]
# Out:
# [{'text': '- My strength lies not in my name,',
#   'start': 0.0,
#   'duration': 3.033},
#  {'text': 'but in the backing of 1.4 billion Indians,',
#   'start': 4.266,
#   'duration': 2.867},
#  {'text': 'and thousands of years of timeless culture\nand heritage.',
#   'start': 7.6,
#   'duration': 3.0},
#  {'text': 'So, wherever I go, I carry with me the\nessence of',
#   'start': 11.8,
#   'duration': 4.366},
#  {'text': 'thousands of years of Vedic tradition, the\ntimeless teachings of Swami Vivekananda,',
#   'start': 16.266,
#   'duration': 5.767}]

# %%
type(transcript_list)
# Out:
# list

# %%
temp_ = ""
for i in transcript_list:
    temp_ += i['text']
len(temp_)
# Out:
# 135379

# %%
[True for i in temp_.split(". ") if len(i) > 500]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
68.76+3.719
# Out:
# 72.479

# %%
chunk_size = 500
chunks = []
timestamps = []

chunk_stack = ""
timestamp_stack = ""

for i in transcript_list:
    the_text = i['text'].strip()
    the_timestamp = i['start']
        
    # if the text is longer than the chunk size
    if len(the_text) >= chunk_size:

        # if previously any chunks exist, append them to the list
        if chunk_stack:
            chunks.append(chunk_stack)
            timestamps.append(timestamp_stack)

            # reset the stack
            chunk_stack = ""
            timestamp_stack = 0

        # append the current chunk
        chunks.append(the_text)
        timestamps.append(the_timestamp)


    # if the text is shorter than the chunk size
    else:
        
        # if chunk and text combined is longer than the chunk size
        if len(chunk_stack := chunk_stack + " " + the_text) > chunk_size:
            
            # split the chunk stack into sentences
            splits = chunk_stack.split(". ")
            temp_chunk_stack = ""
            
            # while the chunk stack is longer than the chunk size
            while(len(chunk_stack := ". ".join(splits)) > chunk_size):
                
                # pop the last sentence from the splits and add it to the temp chunk stack
                temp_chunk_stack = splits.pop() + ". " + temp_chunk_stack
            
            # append the chunk stack and timestamp when the chunk stack is shorter than the chunk size
            chunks.append(chunk_stack.strip())
            timestamps.append(timestamp_stack)

            # reset the stack to temp chunk stack
            chunk_stack = temp_chunk_stack

        # always update the timestamp    
        timestamp_stack = the_timestamp

# %%
len(chunks)
# Out:
# 317

# %%
len(timestamps)
# Out:
# 317

# %% [markdown]
# ChromaDB

# %%
import chromadb
chroma_client = chromadb.PersistentClient("./my_chroma_db")

# %%
chroma_client.list_collections()
# Out:
# [Collection(name=youtube_transcripts)]

# %%
# generating embeddings

from google import genai
from dotenv import load_dotenv
import os
load_dotenv()
gemini_api_key = os.getenv("GOOGLE_API_KEY")

client = genai.Client(api_key=gemini_api_key)

class GeminiEmbedding:
    def __call__(self, input):
        result = client.models.embed_content(
            model="models/text-embedding-004",
            contents=input)

        return [e.values for e in result.embeddings]
    def name(self):
        return "gemini_embedding"

# %%
collection = chroma_client.get_or_create_collection("youtube_transcripts",embedding_function=GeminiEmbedding())

# %%
import numpy as np
import uuid

chunks_len = len(chunks)
for i in range(0,chunks_len,100):

    collection.add(
        documents=chunks[i:i+100],
        ids=[str(uuid.uuid4()) for _ in range(100 if chunks_len >= 100 else chunks_len%100)],
        metadatas=[{
            "time_stamp": t,
            "youtube_id": video_id,
        } for t in timestamps[i:i+100] ]
    )
    chunks_len -= 100

# %%
len(collection.get()['ids'])
# Out:
# 317

# %%
iiii = collection.query( query_texts='pollution in India',n_results=10,include=['documents','metadatas'])

# %%
iiii['documents'][0]
# Out:
# ["He joined the struggle for India’s\nindependence..  And to this day, he continues to deeply\ninfluence the life of every Indian in some\nway. Mahatma Gandhi tried to live by his\nprinciples, and practiced what he\npreached. For example, he strongly advocated for\ncleanliness and practiced it himself. And he made it a point to discuss\ncleanliness wherever he went. Another key factor to consider is India's\nfight for independence",
#  "Whenever we speak of peace, the world\nlistens to us..  Because India is the land of Gautama\nBuddha and Mahatma Gandhi. And Indians aren't hardwired to espouse\nstrife and conflict. We espouse harmony instead. We seek neither to wage war against\nnature, nor to foster strife among\nnations. We stand for peace. And wherever we can act as peacemakers, we\nhave gladly embraced that responsibility. My early life was\nspent in extreme poverty. But we never really felt the burden of\npoverty",
#  'Both nations have ancient cultures and\ncivilizations..  Even in the modern world, they play a\nsignificant role. If you look at historical records, for centuries, India and China have\nlearned from each other. Together, they have always contributed to\nthe global good in some way. Old records suggest that at one point,\nIndia and China alone accounted for more than 50% of the\nworld’s GDP. That’s how massive India’s contribution\nwas',
#  'India was ruled by the Mughals, the British, and\nseveral other foreign powers..  Despite being bound by the shackles of\ncolonial rule for centuries, the flame of independence burned brightly in every corner and nook of India, never\nfading, always fueling the desire for freedom. Millions of people sacrificed their lives\nso the light of freedom could shine on India They laid down their lives for freedom, sacrificing their youth\nbehind prison walls',
#  'In Gujarat, he might be called ‘Ram Bhai,’.  in Tamil Nadu, ‘Ramachandran,’ in\nMaharashtra, ‘Ram Bhau.’ This unique cultural bond is what unites\nIndia as one civilization, Take something as simple as bathing in water. We have a ritual where all the rivers of\nIndia are remembered. They chant: "I am bathing\nwith the waters of all these\nrivers." Ganga, Yamuna, Godavari, Saraswati,\nNarmada, Sindhu, Kaveri, It\'s a sentiment that unites a nation',
#  "What does it take for India to start\nwinning and leading the world in AI?.  - One thing I'm about to say might sound\nstrong, and it may even upset some people. But since you've asked, I'll speak openly\nfrom my heart: No matter what the world does with AI, it\nwill remain incomplete without India. I'm making this statement very\nresponsibly. Tell me. You've heard my speech at the AI Summit in\nParis on global cooperation",
#  'What is the idea that unifies India? What\nis India as a nation? What is the foundational idea that unites.  all of these disparate worlds and\ncommunities and cultures? What would it be? - Look, India is a cultural identity. It is a civilization that dates back\nthousands of years. Consider the vastness of India, over a hundred languages, thousands of dialects. India is so diverse that we have a saying, that every twenty miles the language\nchanges',
#  "- Well, I represent the country that is\nthe land of Lord Buddha..  I represent the country that is the land\nof Mahatma Gandhi. These are the great souls whose teachings,\nwords, actions, and behavior are entirely\ndedicated to peace. And that is why, culturally and\nhistorically, our background is so strong that whenever we speak of peace, the world\nlistens to us. Because India is the land of Gautama\nBuddha and Mahatma Gandhi. And Indians aren't hardwired to espouse\nstrife and conflict",
#  "India, however, has had a variety of\nadministrative systems throughout history..  Many systems were fragmented, scattered,\nand varied across regions. Kings and rulers were numerous, but India's unity lay\nin cultural bonds. Pilgrimage traditions played a key role in\npreserving this unity. Shankaracharya established the four\npilgrimage sites. Even today, millions of people travel from\none place to another for pilgrimage",
#  "As much as there is dedication\nto the land of birth,.  there should be the same sense of\ndedication to the land of work. You should always give your best,\nwherever you are. Because of these rich cultural values, every Indian strives to\ngive their best effort, regardless of their role or\nposition. They don’t wait until they're in senior\nroles; even in smaller roles, Secondly, they never get involved in\nanything questionable or unethical. They tend to remain dedicated to what's\nright and ethical"]

# %%
[i['time_stamp'] for i in iiii['metadatas'][0]]
# Out:
# [3975.366,
#  85.333,
#  6126.533,
#  4012.666,
#  3762.966,
#  9170.0,
#  3675.2,
#  4659.9,
#  3850.066,
#  9434.633]

# %%
kkkk = collection.query( query_texts='pollution in India', n_results=5, where={"youtube_id":"PUtA3W-7_I"})

# %%
kkkk
# Out:
# {'ids': [[]],
#  'embeddings': None,
#  'documents': [[]],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[]],
#  'distances': [[]]}

# %%
if kkkk['documents'][0]:
    print("yes")

# %%
collection.get()
# Out:
# {'ids': ['cc3feec8-9ad3-461d-a003-22c727b1567e',
#   '2152e66b-9471-4517-8305-58ad98564c5f',
#   'ae55d49f-34eb-418f-892b-64e6636c3c98',
#   '8c7bbcca-1c6f-4fb9-8d9d-3aac35b68dca',
#   'cccb804d-c1d6-4274-bf0d-f80ce849f48b',
#   '57d0451f-8885-4ca2-a349-ca2d08f91161',
#   'b276902d-c6f5-4797-a1b8-3aa54205105f',
#   '7b211930-ae99-41cc-8069-2ce85cc0a849',
#   '72669d7e-4e59-4a20-960f-f6c40a050cd1',
#   '21eb9f70-8f91-4d12-b6bb-380c6935abf5',
#   '6b85288d-2c28-4efe-8071-1e67acab8912',
#   'f1b27a3e-2384-4c90-9eff-8244b8273494',
#   'e22ef6aa-a0c4-4723-afc3-a64f6632a8f6',
#   '493cc9dd-46db-4d4c-9962-55e7be3905c2',
#   '79c0e4cb-7d28-4023-b309-4ffd3f0dfa3b',
#   '1d904bf9-f2a1-455a-800d-66abfb4a5af6',
#   '9b746f1e-f81c-423c-92d9-406da4b162e7',
#   '77299bfd-b178-4d4f-bfc7-b703ec1e7a11',
#   '1b7fd9d6-550e-4f42-a0e0-3ef85dede1e0',
#   'ef8a4279-1859-441a-9e12-87d1bb84d2e9',
#   '5a3cf960-ae89-44d1-a08c-dfc5c32900a9',
#   '2b0e9588-6f2f-4675-8188-e402a71e8135',
#   'f07a6a85-61f4-4ea0-a8ce-e60f7028f05c',
#   '8c3f3804-82a5-4792-971f-7895f323f6ee',
#   '601be79a-bd82-4cb1-a6fc-774bf9e3eb9a',
#   '1ca8d80b-0ef2-42fb-b863-eedeab24ccba',
#   '6e77a24a-6f28-4212-a34f-977c5a1d577f',
#   '4a3b2eb9-ba29-4bf5-81cb-06adfd6e6c9f',
#   'e2b218eb-59f5-4f32-a252-ce376c450f94',
#   '2191b31b-c575-4df0-ab6f-8d072cf3b87b',
#   '1d52f6dc-b672-4a1a-87ac-bba52f6a3b70',
#   '86b17694-2bd4-47d3-97ac-ea4e95a024f9',
#   '81ddac47-0c96-48fd-a107-1fef1a8f35bf',
#   '633d8ec4-fdd0-4cdd-8580-d0276279559a',
#   '055000b9-cfb2-481c-9b84-396b488960cd',
#   '468d2426-4817-4fa2-bafb-89cd2cd8e5b7',
#   '97c8bbff-c98a-4656-bb86-e8f67ec2863d',
#   '07bc7d1e-daaa-43ba-963d-346255c29cf2',
#   '126fe628-98a5-49aa-a76b-744baaac146e',
#   'cebdac80-b819-49db-bae1-8f0838c86dc3',
#   '4ce310ff-c011-44f9-9791-120a3a633c2d',
#   'c0b6cd97-990b-4a1b-ae1e-624868e7c4ed',
#   'f22c7b1e-0eff-41e4-8904-c0c75214b8bb',
#   'f56362c2-e64c-4730-8f17-3b4081335ded',
#   '556a4c56-3507-4a7b-81e0-825816e9710c',
#   'a8cc2c2c-2209-40fa-b0fd-72cd7eaa1c9a',
#   '461ca71e-7250-49b0-8915-4155e83d7650',
#   '0fb72da4-afab-4f96-b0df-5b9bb14dd64b',
#   'a9f14a5e-9730-4954-885d-5ce2d2dc0352',
#   '72f373d2-2aff-48df-8d25-413e36fa8881',
#   '98d9c883-4516-40cb-968e-06d2d861b0d8',
#   '0d4242f1-a82e-45f9-9069-6beebc906a52',
#   '02b7d966-5e70-42ba-a4a8-5758acdd7dcc',
#   '2ef9e726-dd70-455a-846a-fe60707474f8',
#   'c583fab8-5e6e-4c31-8b52-24304a13ae2b',
#   'f15c7502-1935-4a40-b04b-8befe1d1b69c',
#   '12d6e933-0f72-407d-898c-1530d3170932',
#   'b5b25595-6a92-49d4-8149-7d86335f1d37',
#   '199c744e-3afe-4146-8226-89dcf690741a',
#   '353d2981-5efa-4fa8-a6ce-1ffc6f30e95c',
#   '3d92ecfc-da60-4f56-b1ca-74659e0e755b',
#   '16df5bd3-fc28-4685-b853-da1905a38d2d',
#   'fb26e114-3bd5-4820-86b1-eed98d39f2ae',
#   '335f7da6-5ccb-40a4-99a3-d14325f3a7cf',
#   '499d1b3b-401f-4162-9a33-7e8f318fd27f',
#   '8228c25a-11b2-4083-83a9-fd08bfcf9528',
#   'c2563e96-6790-4920-accf-97fef24cf031',
#   '2cccea52-1949-4f17-b11c-8e8616b9b771',
#   'd22976d2-3359-4424-9379-8dad473d8863',
#   '137e8fdb-8e0a-4f2f-9a54-e3e15ed552c1',
#   'b0f645e2-519c-4c2e-99b5-95104480c8ee'],
#  'embeddings': None,
#  'documents': ["- My strength lies not in my name, but in the backing of 1.4 billion Indians, and thousands of years of timeless culture\nand heritage. So, wherever I go, I carry with me the\nessence of thousands of years of Vedic tradition, the\ntimeless teachings of Swami Vivekananda, and the blessings, dreams, and aspirations\nof 1.4 billion Indians. When I shake hands with a world leader,\nit's not Modi, but 1.4 billion Indians\ndoing so. So, this isn't my strength at all. It is\nrather the strength of India",
#   "Whenever we speak of peace, the world\nlistens to us..  Because India is the land of Gautama\nBuddha and Mahatma Gandhi. And Indians aren't hardwired to espouse\nstrife and conflict. We espouse harmony instead. We seek neither to wage war against\nnature, nor to foster strife among\nnations. We stand for peace. And wherever we can act as peacemakers, we\nhave gladly embraced that responsibility. My early life was\nspent in extreme poverty. But we never really felt the burden of\npoverty",
#   'You see, someone who is used to wearing\nfine shoes.  will feel their absence when they don’t\nhave them. But for us, we had never worn shoes in our\nlives, so how would we even know that wearing\nshoes was a big deal? We weren’t in a position to compare. That’s just how we lived. When I became Prime Minister, I specially\ninvited Pakistan to my swearing-in ceremony so we could turn over a new leaf. Yet, every noble attempt at fostering\npeace was met with hostility and betrayal',
#   'We sincerely hope that wisdom prevails\nupon them.  and they choose the path of peace. I believe even the people of Pakistan long\nfor peace. Look, regarding what you said about\ncriticism and how I deal with it, if I had to summarize in one sentence, I\nwelcome it. I have a strong belief that criticism is\nthe soul of democracy. I want to tell all young people the\nfollowing: No matter how dark the night may seem, it is still just night, and morning is\nbound to come',
#   "- The following is a\nconversation with Narendra Modi,.  the Prime Minister of India. It was one of the most moving\nconversations and experiences of my life. Allow me here to say a few words about it. Please skip ahead straight to\nour conversation, if you like. Narendra Modi's life story is incredible. He rose from poverty to lead a\nnation of 1.4 billion people, the biggest democracy in the world, where he won epic-scale elections\nfor Prime Minister three times",
#   "As a leader, he fought for\nideas that unite his nation of India,.  a nation that is composed\nof a large number of highly varied and\ndisparate cultures and peoples who have a long history marked by\nreligious, social, and political frictions. He's known for taking decisive,\nat times, controversial actions for which he's loved by hundreds of millions\nof people, and is also criticized by many. We discuss all of this at\nlength in this conversation",
#   "On the world stage,\nhe's respected as a peacemaker and friend.  by most major world leaders, even those\nwhose nations are at war with each other, from United States to China,\nto Ukraine and Russia, to Israel, Palestine, and the Middle East,\nand everywhere else",
#   "Now, at this moment in history,\nit's clear, at least to me, that the flourishing of human civilization\nhangs in the balance, with several wars on the brink of escalation\nto regional and even global conflict, rising tensions between nuclear powers,.  technological developments\nfrom AI to nuclear fusion that aim to completely transform\nsociety and geopolitics as we know it, and, of course, generally,\nincreasing political and cultural turmoil",
#   "So now more than ever,\nwe need great leaders, great peacemakers, who build\nbridges, not destroy them,.  who may preserve the\nidentity of their nations, but still celebrate the common\nhumanity of all of us, all people on Earth. For this and many other reasons,\nthis conversation with Prime Minister Modi was one of the most\nremarkable I've ever had. You may hear such words and think\nthat I'm just enamored by power or access. No, never was, never will be",
#   "I do not idolize anyone,\nespecially those in power..  I'm generally skeptical\nof power, money, and fame because of their natural\ncorrupting influence on the mind, the heart, the soul of a person. The whole point of all the conversations I've had in my life, on mic and off mic, is that I try to see and\nexplore the full complexity of every human being,\nthe good and the bad. I believe we're all the same\nin a deep fundamental sense",
#   "All capable of good, all capable of evil, all carry stories of\npain and stories of hope,.  whether you're a world\nleader or a truck driver, a coal miner or a farmer\nin the American Midwest, and, by the way, I will be talking to a lot of the\nlatter kind of folk this year, off mic, and maybe even on mic, as I\ntravel the US and the world. My brief statements\nhere about Narendra Modi are about both him as a leader\nand especially him as a human being",
#   'In the extensive time I spent with him, I spoke with him off mic and on mic..  It was a deeply personal human interaction characterized by warmth, kindness, humor,\ninner and outer peace, and absolute focus on the\nconversation between us in the present moment as\nif nothing else existed. I have heard from many people that he treats everyone he\nmeets in this empathic way, no matter where they come from, or what their position is in this world',
#   'So, for those and many other reasons, this really was an incredible experience\nI will never forget..  Oh, and by the way, we made captions and\nvoiceover audio tracks available in English,\nHindi, and other languages. You can also listen to the original\nmixed-language version where I speak English and Prime Minister Modi speaks Hindi. Separately, you can choose to turn\non subtitles in your preferred language',
#   'On YouTube, you can switch\nbetween language audio tracks by clicking the Settings gear icon,\nthen clicking Audio Track,.  and then selecting the\nlanguage you prefer. For fully English overdub, select English, for fully Hindi overdub, select Hindi, and to listen to the original\nmixed-language version, where I speak English and Prime\nMinister Modi Speaks Hindi, please select Hindi Latin audio track',
#   "So you can listen either to a version\nthat is all one language, or to the original mixed-language version\nwith subtitles in your preferred language,.  the default is English overdub. All thanks to ElevenLabs and\na great team of translators, we do our best to bring the\nPrime Minister's voice to life with AI voice cloning in English",
#   'I promise that we will\ncontinue to work very hard to break down the barriers\nthat language creates, and try to make these conversations as accessible as possible\nto everyone in the world..  Anyway, let me pause one more\ntime to say a big thank you. What a wild ride this life has been. It\'s an honor for me to be on\nit with all of you. I love you all. This is the "Lex Fridman Podcast." And now, dear friends, here\'s\nthe Prime Minister of India, Narendra Modi',
#   "So, I should also say,\nI’m fasting right now..  It’s been almost two days, 45 hours. So just water, no food, in honor of this\nconversation, just to get in the right mindset, get into\nthe spiritual level. I’ve read that you often\nfast for many days. Can you explain why you fast and where\ndoes your mind go when you fast? - First of all, I’m truly, pleasantly\nsurprised and honored that you’re fasting. All the more because it feels like you're\nfasting as a tribute of respect for me",
#   'My village had certain fascinating\naspects, some of which are quite rare,\neven globally..  When I was in school, there was an elder\nin our village who would regularly tell students,\n"Listen, kids, wherever you go, if you find a carved stone or you find a\nstone with inscriptions on it, or anything with engravings, bring it and\nplace it in this corner of the school. Over time, my curiosity grew, and I\nstarted to understand, I realized that my village had a rich and ancient history',
#   'Discussions at school often revealed more\nfascinating details about its past..  Later, I learned that China even made a\nfilm about it. I had read in a newspaper about a film\nthat mentioned the Chinese philosopher Hiuen Tsang, who had spent a considerable amount of\ntime in my village, having arrived there many centuries ago. Back then, it was a major center for\nBuddhist learning. That’s how I first learned about it. And perhaps, around the 1400s, it was a\nprominent Buddhist educational hub',
#   'There was a Victory Monument from the 12th\ncentury,.  a temple from the 17th century, and in the 16th century, two sisters, Tana\nand Riri, who were renowned musicians. As I uncovered these history traces, I\ngrasped the depth of our heritage. So, when I became Chief Minister, I\ninitiated large-scale excavation projects. The findings from these very projects\nconfirmed that thousands of Buddhist monks\nhad, at one time, studied there',
#   'It was a place where Buddhist, Jain, and\nHindu traditions coexisted harmoniously..  And, for us, history wasn’t just confined\nto books. Every stone spoke, every wall had a story\nto tell. And so when we began the large-scale\nexcavation work, we uncovered findings that hold immense\nhistorical significance. So far, they have discovered evidence\ndating back 2,800 years, proving that this city has remained\nunbroken and eternal for all those 2800\nyears',
#   'They have discovered solid proof of how\nits development unfolded over these\ncenturies..  Now, an international-level museum has\nbeen established there, open to visitors Especially for archaeology students, it\nhas become a major area of study. So, the place where I was born holds its\nown unique historical significance. I see it as my good fortune; some things\nin life unfold beyond our understanding. Kashi became my realm of duty. Now Kashi is also eternal',
#   'Kashi, also\nknown as Banaras or Varanasi,.  is an eternal city that has remained\nvibrant and alive for centuries. Perhaps, it was some divine design that\nled a boy born in Vadnagar to eventually make Kashi his realm of\nduty, living in the embrace of Mother\nGanga. When I think about my family, my father,\nmy mother, my siblings, my uncles, aunts,\ngrandparents, we all grew up together in a\nsmall house. The place we lived was likely even smaller\nthan where we are sitting now',
#   'There was no window, just a small door..  That’s where I was born, that’s where I\ngrew up. Now, when people talk about poverty, it’s natural to discuss it in the context\nof public life. And by those standards, my early life was\nspent in extreme poverty. But we never really felt the burden of\npoverty. You see, someone who is used to wearing\nfine shoes will feel their absence when they don’t\nhave them',
#   'But for us, we had never worn shoes in our\nlives, so how would we even know that wearing\nshoes was a big deal?.  We weren’t in a position to compare. That’s just how we lived. Our mother worked incredibly hard. My father, too.\nHe was extremely hardworking. And he was also extremely disciplined. Every morning, around 4:00 or 4:30 AM, he\nwould leave the house, walk long distances, visit several\ntemples, and then reach his shop. He wore traditional leather shoes,\nhandmade in the village',
#   'The shoes were very tough and sturdy,.  making a distinct ‘tok tok tok’ sound when\nhe walked. People in the village used to say that they could tell the time\njust by hearing his footsteps, "Oh yes," they would say: "Mr. Damodar is\non his way!" Such was his discipline. He worked\ntirelessly, late into the night. Our mother, too, ensured that we never\nfelt the struggles of our circumstances',
#   'There are no shortcuts in\nlife." At our railway stations, there hangs a\nsign.  for those who habitually cross the tracks\ninstead of using the bridge. It reads, "Shortcut will cut you short." I would tell young people the same,\n"Shortcut will cut you short." There are no shortcuts in life. Patience and perseverance are essential. Whatever responsibility we are given, we\nmust pour our heart into it. We should live it with passion, enjoy the\njourney, and find fulfillment in it',
#   'I truly believe that if this mindset is\ncultivated, it transforms life..  Similarly, abundance alone is not enough,\nthere is no guarantee of success. Even a wealthy person who indulges in\ncomfort and idleness will eventually\nwither away. Instead, he must decide, "Yes, I may have\nresources around me, but I must use my abilities to grow them\nfurther." I must contribute more to society with my\nown strength. Even if I am in a good position, there is\nstill so much more to do',
#   'Even if I am not in a good position, there\nis still so much work to do,.  that’s what I believe. I have also noticed that, some people tend\nto think, "I\'ve learned enough, that\'s it." But one should never let the student\nwithin them die. Learning should never\nstop. I believe that as long as I am alive, I\nmust have a purpose. Perhaps I exist to keep learning, to keep\ngrowing',
#   'Now, my mother tongue\nis Gujarati, and We were not very familiar with the Hindi\nlanguage, nor did we know how to speak it eloquently\nor communicate effectively..  But as a child, I used to sit at my\nfather’s tea shop. And at that young age, I got the chance to\nmeet so many people. And every time, I learned something from\nthem. I observed their ways of speaking, their\nexpressions, these things taught me a lot',
#   'Even though I wasn’t in a position to\napply it then, I thought, "If I ever get the chance, why\nnot?" "Why shouldn’t I present myself\nwell?".  So, I believe the desire to learn should\nalways remain alive. And uh, another thing I’ve observed is\nthat most people dream about achieving something or\nbecoming someone. They set big targets, and when they fall short, they feel\ndisappointed',
#   'That’s why, whenever I get a chance to\ntalk to my friends, I tell them: "Instead of dreaming about getting and\nbecoming, dream of doing something.".  If you focus on \'DOING\' something, and let’s say your goal is to reach ten,\nbut you make it to eight. you won’t feel discouraged. You’ll still\nwork toward ten with determination. But if your dream is only to become\nsomething and it doesn’t happen, even your achievements may feel like a\nburden. That’s why we must adjust our mindset in\nlife',
#   'Instead of thinking about what I got or\ndidn’t get,.  the mindset should be, "What\ncan I give? Because true contentment doesn’t bloom on\nits own; it grows from the depths of what\nyou give. - And I should say that this young kid,\none of the things I dreamed of doing is to do this very thing to talk to you\ntoday. So this is a very surreal. At 17, another fascinating part of your\nlife, you left home and spent two years roaming\nin the Himalayas, searching for purpose, for deeper truth,\nfor God',
#   'So not much is known about this period of\nyour life..  You lived a nomadic, minimalist existence\nvery much like a yogi. often sleeping without a roof on your head, what are some memorable spiritual moments,\nrituals, experiences from that time? - It seems like you’ve put in a lot of\neffort. Look, I …. Look, I don’t usually talk much about\nthis, but I can share a few external\naspects of it. I grew up in a very small town. Our life\nwas all about being part of a community',
#   "We lived among people, surrounded by them,\nthat was just how life was..  There was a library in the village, and I\nused to go there often to read books. Whenever I read something from the books,\nI often found myself feeling inspired, thinking, why shouldn't I shape my own\nlife like that? That desire was always there",
#   'When I used to read about Swami\nVivekananda or read about Chhatrapati\nShivaji Maharaj, I would often wonder: how did they live?\nHow did they build such remarkable lives? And for that, I constantly experimented on\nmyself..  Most of my experiments were physical in\nnature, testing my body’s limits. For example, where I lived, winters\nweren’t too harsh, but December nights could get quite cold. But still, at night the cold would bite, it was natural',
#   'So, I just set out and\nbegan the journey..  During my time in the mission, I came across remarkable saints. They\nshowered me with love and blessings. Among them, I formed a special bond with\nSwami Atmasthananda Ji. He lived for nearly a hundred years, a\nlife full of wisdom and service. In his final years, I deeply wished for him to stay with me at\nthe Prime Minister’s residence. But his responsibilities were vast, and he\ncouldn’t come',
#   'However, back when I was Chief Minister,\nhe used to visit, and I was fortunate to receive his\nblessings and guidance..  He once looked at me and said, "Why have you come here? You have a\ngreater purpose to fulfill." "Is your priority your own well-being, or\nis it the welfare of society?" Whatever Swami Vivekananda said was for\nthe betterment of society. He said, "You are meant to serve others." So I…',
# ...
#   {'time_stamp': 1280.233, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1316.0},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1369.733},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1414.6},
#   {'time_stamp': 1457.9, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1498.633},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1552.333},
#   {'time_stamp': 1588.166, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1633.0},
#   {'time_stamp': 1679.7, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 1719.066, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1764.866},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1806.466},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1842.9},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1876.833},
#   {'time_stamp': 1914.633, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 1943.433, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 1980.066},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2019.633},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2070.833},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2113.833},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2146.733},
#   {'time_stamp': 2183.033, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 2230.433, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 2259.833, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 2298.933, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 2333.133, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 2374.333, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 2424.866, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2461.6},
#   {'time_stamp': 2498.5, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2543.066},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2601.1},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2647.966},
#   {'time_stamp': 2693.666, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2741.366},
#   {'time_stamp': 2783.5, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2816.9},
#   {'time_stamp': 2849.166, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2881.9},
#   {'time_stamp': 2916.1, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 2952.866, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 2988.066},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3021.566},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3056.066},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3089.233},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3130.433},
#   {'time_stamp': 3158.266, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3191.766, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3223.866, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3254.4, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3292.633, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3329.566},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3363.7},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3394.266},
#   {'time_stamp': 3435.466, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3460.6, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3504.766, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3548.8},
#   {'time_stamp': 3588.9, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3622.466, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3675.2, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3710.333},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3762.966},
#   {'time_stamp': 3795.866, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3820.666, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3850.066, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 3886.8},
#   {'time_stamp': 3928.633, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 3975.366, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4012.666},
#   {'time_stamp': 4046.966, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4077.466},
#   {'time_stamp': 4116.233, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4157.733},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4209.533},
#   {'time_stamp': 4256.966, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 4297.166, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 4329.9, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 4366.8, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4412.533},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4448.733},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4496.6},
#   {'time_stamp': 4536.1, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 4572.166, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 4611.4, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4659.9},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4699.5},
#   {'time_stamp': 4732.7, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4771.366},
#   {'time_stamp': 4815.0, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 4867.2, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 4910.5},
#   {'time_stamp': 4952.9, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 4985.766, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 5027.3, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 5064.433, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5113.7},
#   {'time_stamp': 5159.966, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 5199.733, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5232.366},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5270.366},
#   {'time_stamp': 5306.033, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5335.833},
#   {'time_stamp': 5351.7, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 5381.733, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5411.233},
#   {'time_stamp': 5446.366, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5483.566},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5527.566},
#   {'time_stamp': 5571.166, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5610.9},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5638.9},
#   {'time_stamp': 5675.633, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5722.566},
#   {'time_stamp': 5766.366, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5792.966},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5820.266},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5850.533},
#   {'time_stamp': 5884.0, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 5915.633},
#   {'time_stamp': 5952.2, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp': 5992.766, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 6029.533},
#   {'time_stamp': 6076.766, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 6126.533},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 6165.933},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 6209.566},
#   {'time_stamp': 6248.633, 'youtube_id': 'ZPUtA3W-7_I'},
#   {'time_stamp':

#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 11793.1},
#   {'youtube_id': 'ZPUtA3W-7_I', 'time_stamp': 11828.6}]}

# %%
kkkk
# Out:
# [["He joined the struggle for India’s\nindependence..  And to this day, he continues to deeply\ninfluence the life of every Indian in some\nway. Mahatma Gandhi tried to live by his\nprinciples, and practiced what he\npreached. For example, he strongly advocated for\ncleanliness and practiced it himself. And he made it a point to discuss\ncleanliness wherever he went. Another key factor to consider is India's\nfight for independence",
#   "Whenever we speak of peace, the world\nlistens to us..  Because India is the land of Gautama\nBuddha and Mahatma Gandhi. And Indians aren't hardwired to espouse\nstrife and conflict. We espouse harmony instead. We seek neither to wage war against\nnature, nor to foster strife among\nnations. We stand for peace. And wherever we can act as peacemakers, we\nhave gladly embraced that responsibility. My early life was\nspent in extreme poverty. But we never really felt the burden of\npoverty",
#   'Both nations have ancient cultures and\ncivilizations..  Even in the modern world, they play a\nsignificant role. If you look at historical records, for centuries, India and China have\nlearned from each other. Together, they have always contributed to\nthe global good in some way. Old records suggest that at one point,\nIndia and China alone accounted for more than 50% of the\nworld’s GDP. That’s how massive India’s contribution\nwas',
#   'India was ruled by the Mughals, the British, and\nseveral other foreign powers..  Despite being bound by the shackles of\ncolonial rule for centuries, the flame of independence burned brightly in every corner and nook of India, never\nfading, always fueling the desire for freedom. Millions of people sacrificed their lives\nso the light of freedom could shine on India They laid down their lives for freedom, sacrificing their youth\nbehind prison walls',
#   'In Gujarat, he might be called ‘Ram Bhai,’.  in Tamil Nadu, ‘Ramachandran,’ in\nMaharashtra, ‘Ram Bhau.’ This unique cultural bond is what unites\nIndia as one civilization, Take something as simple as bathing in water. We have a ritual where all the rivers of\nIndia are remembered. They chant: "I am bathing\nwith the waters of all these\nrivers." Ganga, Yamuna, Godavari, Saraswati,\nNarmada, Sindhu, Kaveri, It\'s a sentiment that unites a nation']]

# %%
iiii
# Out:
# {'ids': [['6f7a2e26-0ce0-4480-a7e3-75c254d319bd',
#    '718108fd-2e8a-422d-b58b-2a093416f04b',
#    'dab0f610-23d3-4e7d-ad85-ab3119b872f0',
#    '5876c90e-6673-48f5-b323-6651653d9c5c',
#    '80e0987b-fd3e-45fe-b9d6-a6d3286737ff',
#    '22a50694-46a9-4a70-8b9f-332809b1c775',
#    'f6581c15-cf3a-46b2-afc2-eeeb06d8638a',
#    '1aac7aa1-91f2-4aa3-8ea0-f8e236515302',
#    'afaeaf26-2e84-429e-ba26-07b1139c9fde',
#    '22b3dc01-51b3-47c4-a172-a7ebebfa0796']],
#  'embeddings': None,
#  'documents': [["Um next topic which is somewhat related is that the air quality in India we we recently went to India I think it was in December and it's the opposite of HPO because the pollution there was so bad that we almost canled the trip last.  minute. I think sometimes like the the levels were hundreds of times higher than the recommended uh PM PMI. Is that what it is? PMI limits. Yeah. Am I? Yeah. PMI. PM2.5. PM2.5. Yeah. Yeah. PM PM2.5. Yeah",
#    "And it carries these toxins, these nitrogen, nitrogen oxides, sulfur dioxides, carbon monoxides that come from industrial pollution, you know, vehicle emissions, smoke and uh it causes all kinds of things like it can put you at risk of lung disease, cardiovascular damage, neural generation, you know, and like you're.  saying Kate, if they actually India would do would do better for their population to address air pollution than solve all cancer. It would actually extend lifespan more",
#    'Which is wild that people are living in this pollution every single day. And I think Brian, you said.  that um after you and Mike were doing the a look at the literature that it actually potentially is that pollution caused more shortening of life than cancer did. So that India might even be better off solving pollution for its country rather than trying to go after something like cancer. So what happened? Why was it so controversial? Yeah. So we we decided to go to India last year',
#    "So yeah, we got there and it just like um as we got more and more in the Indian culture and and talked about this topic, it just became increasingly clear that it's really a representation of this more systematic problem where they're literally breathing death and everyone is so.  normalized to it that they couldn't even see it anymore. And so just like for for context on this like the the PM 2.5 is is a marker of of of a health danger",
#    "So, but being.  there in person, it was actually intense. Like much more than I'd imagined. When you said like they're breathing death and they're normalized to it, it makes me think about how in America you're eating death and you're normalized to it. Like that our culture is just so So yeah, I guess like a note that um this really isn't about um India's inability to solve pollution. It's about the things that are right in front of our eyes that we can't see that we learn to live with",
#    "And so I think within that couple days like we it was like it blew up in India like the.  whole of India was talking about this topic and from the cover of all the major publications there it became a really really big topic. Yeah. For context on this, this was actually really emotionally stressful because the the PM 2.5 levels when we were there, I think they averaged around 75 to 120 depending upon the city we were in. And that's equal to around 3 to five cigarettes per day",
#    "So, Mike, what would you say for you people all over the world that are listening to this? Um, how should they think about being aware of air quality and what things can they do to improve uh their health amidst air quality challenges they may face in their.  region? Yeah, I mean, so first thing I wanted to say is that this isn't isolated to India. Air quality is an issue all over the world",
#    'got so alarmed I called my friend Kate I.  called you and I was like I think we need to cancel this trip like it is really bad. I mean, I knew that the air quality in India was bad, but like not to this level. And um so I talked to my friend and he\'s like, "You know what? It\'s fine. Um the hotel we\'re staying at has air purifiers throughout the hotel. It\'s all monitored. It\'s on these screens. You\'re fine." And so we went there and once we\' landed, it was just an entirely different world',
#    "Like I.  guess it's one thing to see see high levels of of toxins on a um an air quality map, but when you're there and you're breathing it, you can just smell and feel the the pollution in your nose and lungs and throat. And it was a shocking arrival",
#    "It was actually really emotionally.  stressful because the PM2.5 levels when we were there, I think they averaged around 75 to 120 depending upon the city we were in. And that's equal to around 3 to five cigarettes per day"]],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'time_stamp': 971.199, 'youtube_id': 'XVJaqRSrEZA'},
#    {'youtube_id': 'XVJaqRSrEZA', 'time_stamp': 1174.799},
#    {'time_stamp': 994.16, 'youtube_id': 'XVJaqRSrEZA'},
#    {'youtube_id': 'XVJaqRSrEZA', 'time_stamp': 1138.559},
#    {'youtube_id': 'XVJaqRSrEZA', 'time_stamp': 1202.96},
#    {'youtube_id': 'XVJaqRSrEZA', 'time_stamp': 1258.0},
#    {'youtube_id': 'XVJaqRSrEZA', 'time_stamp': 1464.48},
#    {'time_stamp': 1090.32, 'youtube_id': 'XVJaqRSrEZA'},
#    {'youtube_id': 'XVJaqRSrEZA', 'time_stamp': 1120.72},
#    {'youtube_id': 'XVJaqRSrEZA', 'time_stamp': 56.96}]],
#  'distances': [[0.6781100034713745,
#    0.6936196088790894,
#    0.7031624913215637,
#    0.7396321892738342,
#    0.755406379699707,
#    0.7807731628417969,
#    0.781481146812439,
#    0.8301689028739929,
#    0.9703390598297119,
#    0.9741279482841492]]}

# %%
client.models.embed_content(
        model="models/text-embedding-004",
        contents='who are you').embeddings[0].values
